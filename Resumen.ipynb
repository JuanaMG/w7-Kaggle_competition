# %% [markdown]
# # Kaggle Competition
#
# &nbsp;
#
# **1. Exploración de los datos y elección de variables a incluir en el estudio.**
#
# Inicialmente son las siguientes:
#     - 'host_is_superhost'
#     - 'latitude',
#     - 'longitude',
#     - 'property_type',
#     - 'accommodates',
#     - 'bedrooms',
#     - 'price',
#     - 'minimum_nights',
#     - 'maximum_nights'
#
# Posteriormente se han añadido:
#     - 'neighbourhood'
#     - 'host_listings_count'
#
# &nbsp;
#
# **2. Limpieza de datos.**
#     - 'bedrooms',
#     - 'neighbourhood',
#     - 'property_type'
#
# &nbsp;
#
# **3. Crear variables dummies para *'property_type'*, *'neighbourhood'*, *'host_is_superhost'*.**
#
# &nbsp;
#
# **4. Modelos**
#
#
#     * Regresión lineal múltiple
#     * Random Forest Regressor
#     * Extreme Gradient Boosting
#     * Catboost
#
#     ** Pruebas con variables muy correlacionadas.
#
# &nbsp;
#
# **5. Mejores resultados en cada prueba**
#
#
#     * RFR con todas variables iniciales - test size = 0.2
#
# Train R2: 0.8539
# Test R2: 0.40167
# rmse: 99.3088
#
#     * RFR con todas las vbles - test_size = 0.1
#
# Train R2: 0.8794
# Test R2: 0.4504
# rmse: 90.2534
#
#     * Catboost todas las vbles - test_size = 0.1
#
# Train R2: 0.8891
# Test R2: 0.4732
# rmse: 88.35807
#
#     * Añadir columna 'neighbourhood' - RFR - test_size = 0.1
#
# Train R2: 0.8613
# Test R2: 0.3990
# rmse: 99.5260
#
#     * Añadir columna 'host_listings_count' - RFR - test_size = 0.2
#
# Train R2: 0.8946
# Test R2: 0.3959
# rmse: 102.69
